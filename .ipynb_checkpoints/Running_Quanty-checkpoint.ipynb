# %%
# %reset -f
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
import os
import sys

script_dir = 'C:/Users/bpoult/Documents/Research/X-ray_Simulation_Software/CTM_machine_learning/simulation_scripts/'
sys.path.append(script_dir)

from generate_inp_rixs import generate_inp_rixs
from generate_inp_quanty import generate_inp_quanty
from run_quanty_sim import run_quanty_sim

# %% [markdown]
# ## **This cell generates input files for quanty RIXS calculations**

# %%
#### Oh ####

output_path = 'C:/Users/bpoult/Documents/Research/X-ray_Simulation_Software/Simulations/Co/CoTerpy/3.25.2026_CoTerpySimulations/ES_Oh/'
fname_quanty = 'ES_Oh.inp_quanty'
fname_rixs = 'ES_Oh.inp_rixs'


params_i = {
    'NPsi_i': 50,
    'tenDq_3d_i': 3.0,
    'Ds_3d_i': -0.0055,
    'Dt_3d_i': -0.013,
    'scalef2_3d3d_i': 0.58,
    'scalef4_3d3d_i': 0.8,
    'scale_3dSOC_i': 0.8,
    'U_3d_3d_i': 0,
}

params_f = {
    'NPsi_f': 50,
    'tenDq_3d_f': 3.0,  
    'Ds_3d_f': -0.0055,
    'Dt_3d_f': -0.013,
    'scalef2_3d3d_f': 0.58,
    'scalef4_3d3d_f': 0.8,
    'scale_3dSOC_f': 0.8,
    'U_3d_3d_f': 0,
    'U_2p_3d_f': 0,
    'scalef2_2p3d': 0.2,
    'scaleg': 0.6,
    'scale_2pSOC': 0.8,
    'E_2p': 778,
}

params_rixs = {
    'initial_state': 14, # 1 is ground state, higher numbers are higher lying states - I've been checking using Crispy, but will probably write my own.
    'energy_start': 765,
    'energy_end': 800,
    'energy_step': 0.1,
    'loss_start': -6,
    'loss_end': 15,
    'loss_step': 0.05,
    'FWHM_lorentz1': 1,
    'FWHM_lorentz1b': 0.7,
    'FWHM_lorentz2': 0.1,
    'Eshift': 0.0,
    'L3_L2_split': 783,
    'pol': 0,
}

generate_inp_quanty(params_i,params_f,output_path,fname_quanty)
generate_inp_rixs(params_rixs,output_path,fname_rixs)
# Out:
# WindowsPath('C:/Users/bpoult/Documents/Research/X-ray_Simulation_Software/Simulations/Co/CoTerpy/3.25.2026_CoTerpySimulations/ES_Oh/ES_Oh.inp_rixs')

# %% [markdown]
# ## **This cell runs the quanty script with the above parameters**

# %%
lua_file = 'greenMLCT_Co3d6_D4h_RCN_conf_job.lua'
lua_file = 'groundstate.lua'

lua_file_path = 'C:/Users/bpoult/Documents/Research/X-ray_Simulation_Software/QuantyRIXS_ML/'
result = run_quanty_sim(folder_path=output_path,lua_file=lua_file)
print("STDOUT:", result.stdout)
# Out:
# STDOUT: =============================================================
# ====    written by Maurits W. Haverkort,                 ====
# ====    Yi Lu, Robert Green, Sebastian Macke,            ====
# ====    Marius Retegan, Martin Brass, and Simon Heinze   ====
# ====    (cc) 1995 - 2022 code and binaries released      ====
# ====    under creative commons CC-BY lisence             ====
# ====    www.quanty.org                                   ====
# ====    Beta version, be critical and report errors!!!   ====
# =============================================================
# ====    Version 0.7 beta                                 ====
# ====            compiled at: Oct  7 2022 at 10:09:06     ====
# =============================================================
# ====    When used in scientific publications please cite ====
# ====    one of the following papers as appropriate with  ====
# ====    respect to the methods used in your publication: ====
# ====    Phys. Rev. B 85, 165113 (2012)                   ====
# ====    Phys. Rev. B 90, 085102 (2014)                   ====
# ====    Euro Phys. Lett. 108, 57004 (2014)               ====
# ====    J. of Phys.: Conf. Series 712, 012001 (2016)     ====
# ====    New Journal of Physics 22 (9), 093018 (2020)     ====
# =============================================================
# Program executed on: Wed Mar 25 21:10:20 2026
# Running on host    : Windows
# number of available processors              : 20
# maximum number of threads in parallel region: 20
# Smallest positive float  : 2.225074E-308
# Smallest deviation from 1: 2.220446E-016
#
# Quanty configuration file ES_Oh.inp_quanty
#
# NPsi_Initial = 50
# NPsi_Final = 50
# tenDq_3d_i = 3.0
# tenDq_3d_f = 3.0
# Ds_3d_i = -0.0055
# Ds_3d_f = -0.0055
# Dt_3d_i = -0.013
# Dt_3d_f = -0.013
# scalef2_3d3d_i = 0.58
# scalef2_3d3d_f = 0.58
# scalef4_3d3d_i = 0.8
# scalef4_3d3d_f = 0.8
# scalef2_2p3d = 0.2
# scaleg = 0.6
# scale_3dSOC_i = 0.8
# scale_3dSOC_f = 0.8
# scale_2pSOC = 0.8
# U_3d_3d_i = 0
# U_3d_3d_f = 0
# U_2p_3d_f = 0
# E_2p = 778
#
# Spectra configuration file ES_Oh.inp_rixs
#
# initial_state = 14
# energy_start = 765
# energy_end = 800
# energy_step = 0.1
# loss_start = -6
# loss_end = 15
# loss_step = 0.05
# FWHM_lorentz1 = 1
# FWHM_lorentz1b = 0.7
# FWHM_lorentz2 = 0.1
# Eshift = 0.0
# L3_L2_split = 783
# pol = 0
#
# Diagonal values of the initial crystal field Hamiltonian:
# ================
# Irrep.         E
# ================
# a1g        1.889
# b1g        1.802
# b2g       -1.198
# eg        -1.246
# ================
#
# Start of BlockGroundState. Converge 50 states to an energy with relative variance smaller than 1.490116119384766E-006
#
# Start of BlockOperatorPsiSerialRestricted
# Outer loop   1, Number of Determinants:       210       210 last variance 0.000000000000000E+000
# Start of BlockOperatorPsiSerialRestricted
# Start of BlockGroundState. Converge 50 states to an energy with relative variance smaller than 1.490116119384766E-006
#
# Start of BlockOperatorPsiSerial
# State    <E>      <S^2>     <L^2>     <J^2>     <l.s>     <Nb2g>    <Neg>     <Nb1g>    <Na1g>
#   1:   -0.000     0.012    26.226    26.227    -0.357     1.980     3.962     0.029     0.028
#   2:    1.610     2.093    17.394    20.847    -0.692     1.067     3.880     0.990     0.063
#   3:    1.612     2.115    17.328    20.006    -0.624     1.038     3.904     0.998     0.060
#   4:    1.612     2.115    17.328    20.006    -0.624     1.038     3.904     0.998     0.060
#   5:    1.708     2.137    17.231    21.096    -0.850     1.937     2.997     0.294     0.771
#   6:    1.709     2.139    17.203    20.316    -0.774     1.953     2.981     0.305     0.761
#   7:    1.722     2.225    17.068    19.101    -0.589     1.918     2.997     0.370     0.716
#   8:    1.722     2.225    17.068    19.101    -0.589     1.918     2.997     0.370     0.716
#   9:    1.729     2.254    17.048    18.855    -0.579     1.962     2.946     0.445     0.648
#  10:    1.739     2.300    16.983    18.021    -0.284     1.908     2.991     0.456     0.645
#  11:    1.956     5.928     6.212    17.455    -0.886     1.077     2.940     0.984     1.000
#  12:    1.956     5.928     6.212    17.455    -0.886     1.077     2.940     0.984     1.000
#  13:    1.963     5.890     6.336    17.737    -0.846     1.242     2.783     1.000     0.975
#  14:    1.981     5.685     6.980    14.479    -0.299     1.055     3.018     0.970     0.956
#  15:    1.983     5.741     6.793    14.513    -0.529     1.210     2.850     0.989     0.951
#  16:    1.983     5.741     6.793    14.513    -0.529     1.210     2.850     0.989     0.951
#  17:    1.992     5.802     6.593    13.249    -0.499     1.270     2.776     0.984     0.970
#  18:    2.002     5.723     6.871    13.774    -0.207     1.327     2.738     0.986     0.949
#  19:    2.038     5.887     6.389     8.563     0.789     1.009     3.017     1.000     0.974
#  20:    2.038     5.887     6.389     8.563     0.789     1.009     3.017     1.000     0.974
#  21:    2.071     5.888     6.373     8.867     0.669     1.791     2.235     0.976     0.998
#  22:    2.074     5.821     6.603     9.225     0.807     1.759     2.283     0.965     0.993
#  23:    2.074     5.821     6.603     9.225     0.807     1.759     2.283     0.965     0.993
#  24:    2.076     5.721     6.940    10.089     0.942     1.767     2.299     0.943     0.991
#  25:    2.079     5.668     7.126    10.005     1.117     1.707     2.371     0.940     0.982
#  26:    2.203     2.199    17.882    20.818    -0.174     1.604     3.276     0.523     0.597
#  27:    2.203     2.199    17.882    20.818    -0.174     1.604     3.276     0.523     0.597
#  28:    2.203     2.200    17.914    20.258    -0.094     1.918     2.961     0.669     0.452
#  29:    2.209     2.174    17.901    20.911    -0.035     1.476     3.413     0.459     0.652
#  30:    2.209     2.199    17.838    20.300     0.064     1.930     2.954     0.674     0.442
#  31:    2.234     2.078    18.194    19.652     0.391     1.939     2.974     0.755     0.332
#  32:    2.247     2.061    18.245    19.250     0.444     1.360     3.557     0.287     0.796
#  33:    2.247     2.061    18.245    19.250     0.444     1.360     3.557     0.287     0.796
#  34:    2.258     2.001    18.424    19.195     0.592     1.492     3.440     0.382     0.687
#  35:    2.680     0.025    32.864    32.911    -0.019     1.011     3.965     0.999     0.025
#  36:    2.789     0.020    32.902    32.937    -0.050     1.983     2.992     0.299     0.726
#  37:    2.789     0.020    32.902    32.937    -0.050     1.983     2.992     0.299     0.726
#  38:    3.791     0.014    18.880    18.894    -0.252     1.924     2.979     0.747     0.350
#  39:    3.791     0.014    18.880    18.894    -0.252     1.924     2.979     0.747     0.350
#  40:    3.806     0.015    18.898    18.913    -0.257     1.053     3.850     0.094     1.003
#  41:    4.406     2.012    23.705    27.118    -0.468     1.037     2.959     1.181     0.824
#  42:    4.408     2.021    23.821    25.878    -0.420     1.026     2.967     1.290     0.717
#  43:    4.412     2.020    23.855    25.401    -0.260     1.002     2.991     1.299     0.708
#  44:    4.414     2.005    23.697    26.962    -0.230     1.000     2.997     1.184     0.819
#  45:    4.414     2.011    23.744    26.233    -0.207     1.030     2.966     1.248     0.756
#  46:    4.414     2.011    23.744    26.233    -0.207     1.030     2.966     1.248     0.756
#  47:    4.494     2.005    24.559    27.089    -0.467     1.498     2.499     0.836     1.167
#  48:    4.494     2.005    24.559    27.089    -0.467     1.498     2.499     0.836     1.167
#  49:    4.494     2.014    24.383    25.688    -0.369     1.604     2.390     0.793     1.213
#  50:    4.511     2.000    24.731    27.312    -0.146     1.005     2.998     1.060     0.937
# Finished.

# %%
plt.close('all')
# Define positions and labels
lines = [
    (0, 'GS'),
    (1.8, '3MC'),
    (2.15, '5MC'),
    (2.48, '3MC'),
    (2.89, '1MC'),
    (4.22, '1MC')
]

# Define colors for each unique label using colorblind-friendly palette
color_map = {
    'GS': '#000000',    # Black
    '3MC': '#E69F00',   # Orange
    '5MC': '#56B4E9',   # Sky blue
    '1MC': '#009E73'    # Bluish green
}

plt.figure(figsize=(4, 4), dpi=100)

# Track which labels have been added to legend
added_labels = set()

# Plot horizontal lines
for position, label in lines:
    # Only add label if it's the first occurrence (for legend)
    if label not in added_labels:
        plt.axhline(y=position, color=color_map[label], linewidth=2, 
                   label=label, alpha=0.8)
        added_labels.add(label)
    else:
        plt.axhline(y=position, color=color_map[label], linewidth=2, alpha=0.8)

# Labels and styling
plt.ylabel('Energy (eV)', fontsize=12, fontweight='bold')
plt.title('Electronic State Energies', fontsize=14, fontweight='bold', pad=15)

# Legend - bottom right
plt.legend(frameon=True, fancybox=True, shadow=True, fontsize=11, loc='lower right')

# Grid and styling
plt.xlim(0, 1)  # Adjust as needed
plt.tight_layout()
plt.xticks([])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')
